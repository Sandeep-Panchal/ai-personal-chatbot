# %%
messages=[{'role': 'user', 'content': 'i want to learn langgraph'},
                  {'role': 'assistant', 'content': "LangChain is a popular framework for developing applications with large language models (LLMs)."
                  "It focuses on how to integrate LLMs like GPT-3, ChatGPT and others into your own projects."
                  "Do you have any questions about LangChain specifically? I can help you understand it better if you'd like! "
                  "Just let me know what interests you about LangChain."},
                  {'role': 'user', 'content': 'i want to learn langgraph'},
                  {'role': 'assistant', 'content': "LangChain is a popular framework for developing applications with large language models (LLMs)."
                  "It focuses on how to integrate LLMs like GPT-3, ChatGPT and others into your own projects."
                  "Do you have any questions about LangChain specifically? I can help you understand it better if you'd like! "
                  "Just let me know what interests you about LangChain."}]
                  


message = "\n".join(f"{i['role']}: {i['content']}" for i in messages)
print(message)
print(type(message))
# Out:
# user: i want to learn langgraph
# assistant: LangChain is a popular framework for developing applications with large language models (LLMs).It focuses on how to integrate LLMs like GPT-3, ChatGPT and others into your own projects.Do you have any questions about LangChain specifically? I can help you understand it better if you'd like! Just let me know what interests you about LangChain.
# user: i want to learn langgraph
# assistant: LangChain is a popular framework for developing applications with large language models (LLMs).It focuses on how to integrate LLMs like GPT-3, ChatGPT and others into your own projects.Do you have any questions about LangChain specifically? I can help you understand it better if you'd like! Just let me know what interests you about LangChain.
# <class 'str'>
